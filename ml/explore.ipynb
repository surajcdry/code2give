# %%
import pandas as pd

# %%
edges_df = pd.read_csv('edges.csv')
nodes_df = pd.read_csv('nodes.csv')

# %%
edges_df.describe()
# Out:
#               source         target         weight
# count  111526.000000  111526.000000  111526.000000
# mean     4548.317576    4548.317576       1.542482
# std      2666.222250    2666.222250       4.904134
# min         0.000000       0.000000       0.497513
# 25%      1958.000000    1958.000000       0.596176
# 50%      5554.000000    5554.000000       0.768473
# 75%      6923.000000    6923.000000       1.194621
# max      8504.000000    8504.000000     100.000000

# %%
nodes_df.describe()
# Out:
#           node_idx     latitude    longitude  resource_type  \
# count  8510.000000  8510.000000  8510.000000    8510.000000
# mean   4254.500000    38.464994   -78.476180       0.111633
# std    2456.769729     3.969047     7.210521       0.359213
# min       0.000000    24.552151  -123.802787       0.000000
# 25%    2127.250000    38.331577   -82.332281       0.000000
# 50%    4254.500000    39.963304   -76.069232       0.000000
# 75%    6381.750000    40.729326   -74.130945       0.000000
# max    8509.000000    47.864010   -69.546698       2.000000
#
#        rating_normalized  wait_time_normalized  magnet_score  barrier_score  \
# count        8510.000000           8510.000000   8510.000000    8510.000000
# mean            0.799813              0.275554      0.013220       0.087944
# std             0.099777              0.222682      0.047304       0.154024
# min             0.333333              0.000000      0.000000       0.000000
# ...
